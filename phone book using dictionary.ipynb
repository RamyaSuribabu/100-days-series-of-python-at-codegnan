# %%
###### Creating contact book
ph_book={}
def add_contact(name: str,number:int):
    # check name is exists in ph_book or not
    if name not in ph_book:
        ph_book[name]=number
        print("contact saved")
    else:
        print("name already exists")
# update mobile no. in ph_book
def update_num(name:str,number:int):
    if name not in ph_book:
        print("contact not exists")
    else:
        ph_book.update({name : number})
        print("contact number is successfully updates")
# deleting contact
def delete_contact(name : str):
    if name in ph_book:
        ph_book.pop(name)
        print("successfully deleted")
    else:
        print("cannot not exist")
#get contact:
def get_number(name: str):
    number = ph_book.get(name,'name not found')
    print("the contact number update is:",number)
# print all contacts
def all_contacts():
    #if contact book is empty 
    if not ph_book:
        print("noo contacts found")
        return 
    for name,number in ph_book.items():
        print(f'{name} : {number}')

if __name__ == '__main__':
    print("welcome to the contact book")
    while True:
        print("enter the name ")
        name=input()
        print("enter the mobile number")
        number=int(input())
        print("enter 1.to add the contact,2.to update the numeber,3.to delete the contact,4. to get the number,5.to print all the contacts")
        choice=int(input())
        if choice==1 :
            print(add_contact(name,number))
        elif choice == 2:
            print(update_num(name,number)) 
        elif choice == 3:
            print(delete_contact(name,number))
        elif choice == 4:    
            print(get_number(name))
        elif choice == 5:
            print(all_contacts()) 
        elif choice == 6:
            print("you entered the invalid choice")
            break
# Out:
# welcome to the contact book
# enter the name
#  1
# enter the mobile number
#  4567
#  1
# enter 1.to add the contact,2.to update the numeber,3.to delete the contact,4. to get the number,5.to print all the contacts
# contact saved
# None
# enter the name
#  6
# enter the mobile number
#  6
#  6
# enter 1.to add the contact,2.to update the numeber,3.to delete the contact,4. to get the number,5.to print all the contacts
# you entered the invalid choice

# %%
# creating contact book
ph_book={}
def add_contact(name:str,number:int):
    # check name is exists in ph_book or not
    if name not in ph_book:
        ph_book[name] = number
        print("contact saved")
    else :
        print("name already saved")
# update mobile no. in ph_book
def update_number(name:str,number:int):
     if name not in ph_book:
        print("contact not exists")
     else :
        ph_book.update = ({name:number}) # updating mobile number
        print("mobile number is updated")
# delete contact 
def delete_contact(name:str):
    if name in ph_book:
        ph_book.pop(name)
        print("successfully deleted")
    else:
        print("contact not found")
# To get a contact no.
def get_number(name:str):
    if name in ph_book:
        number = ph_book.get(name, 'name is not found')
        print("The contact number update is:", number)
# print all contacts
def all_contacts( ):
    # if contact book is empty
    if not ph_book:
        print("no contacts found")
    for name,number in ph_book.items( ):
        print(f'{name} : {number}')

# main
def main():
    print("Welcome to the Contact Book")

    while True:
        print("\n1. Add Contact")
        print("2. Delete Contact")
        print("3. Get Contact Number")
        print("4. View All Contacts")
        print("5. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            name = input("Enter name: ")
            number = input("Enter number: ")
            add_contact(name, number)

        elif choice == "2":
            name = input("Enter name to delete: ")
            delete_contact(name)

        elif choice == "3":
            name = input("Enter name to search: ")
            get_number(name)

        elif choice == "4":
            all_contacts()

        elif choice == "5":
            print("Thank you for using contact book")
            break

        else:
            print("Invalid choice")

main()
# Out:
# Welcome to the Contact Book
#
# 1. Add Contact
# 2. Delete Contact
# 3. Get Contact Number
# 4. View All Contacts
# 5. Exit
# Enter your choice:  1
# Enter name:  ramya
# Enter number:  789
# contact saved
#
# 1. Add Contact
# 2. Delete Contact
# 3. Get Contact Number
# 4. View All Contacts
# 5. Exit
# Enter your choice:  5
# Thank you for using contact book
