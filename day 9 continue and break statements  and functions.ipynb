# %%
for i in range (1,6):
    if i==3:
        continue
    print(i)
else:                            #else block is executed when break is not executed 
    print("program done")
# Out:
# 1
# 2
# 4
# 5

# %%
for i in range (1,6):
    if i==3:
        break
    print(i)
else:
    print("program done")
# Out:
# 1
# 2

# %%
a=10
b=20
sum=a+b
print(sum)
# Out:
# 30

# %%
def sum(a,b):
    sum=a+b
    return sum
result=sum(10,2)
print(result)
# Out:
# 12

# %% [markdown]
# ### basic calculator using functions

# %%
def add(a,b):
    r=a+b
    return r
def sub(a,b):
    s=a-b
    return s
def mul(a,b):
    t=a*b
    return t
def div(a,b):
    if b==0 :
        return "zero division not possible"
    u=a/b
    return u

if __name__ == "__main__" :
    print("welcome to small level calculator") 

    
r=add(20,10)
print(r)
s=sub(20,10)
print(s)
t=mul(20,10)
print(t)
u=div(20,10)
print(u)
# Out:
# 30
# 10
# 200
# 2.0

# %%
def add(a,b):
    r=a+b
    return r
def sub(a,b):
    s=a-b
    return s
def mul(a,b):
    t=a*b
    return t
def div(a,b):
    if b==0 :
        return "zero division not possible"
    u=a/b
    return u

if __name__ == "__main__" :
    print("welcome to small level calculator") 
n1=int(input())
n2=int(input())
print("1 for addition /n 2 for subtraction /n 3 for multiplication /n 4 for division  ")
choice=int(input("enter your choice"))
if choice ==1:
    print("sum of 2 numbers is",add(n1,n2))
elif choice ==2:
     print("subtraction of 2 numbers is",sub(n1,n2))
elif choice ==3:
     print("multiplication  of 2 numbers is",mul(n1,n2))
elif choice ==4:
     print("division of 2 numbers is",div(n1,n2))
# Out:
# welcome to small level calculator
